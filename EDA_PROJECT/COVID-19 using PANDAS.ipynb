# %% [markdown]
# # IMPORTING PYTHON LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading CSV File using Pandas

# %%
data = pd.read_csv("country_wise_latest.csv")

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# # HEAD AND TAIL

# %% [markdown]
# ## .head()
# This function returns the first n rows for the object based on position. It is useful for quickly testing if your object has the right type of data in it

# %%
data.head(10)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
# 7              Armenia      37390     711      26665   10014         73
# 8            Australia      15303     167       9311    5825        368
# 9              Austria      20558     713      18246    1599         86
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %% [markdown]
# ## .tail()
# Return the last n rows.

# %%
data.tail(5)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# # DATA INFORMATION

# %% [markdown]
# ## .info()
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# # SHAPE

# %% [markdown]
# ## .shape
# Return a tuple representing the dimensionality of the DataFrame.

# %%
data.shape
# Out:
# (187, 15)

# %% [markdown]
# # DATA TYPES

# %%
data.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %% [markdown]
# # SIZE

# %%
data.size
# Out:
# 2805

# %% [markdown]
# # DESCRIBE

# %%
data.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# # Loc and iloc

# %% [markdown]
# ## .loc()
# Select rows and columns by labels

# %%
data.loc[:5,['Deaths','Active']]
# Out:
#    Deaths  Active
# 0    1269    9796
# 1     144    1991
# 2    1163    7973
# 3      52      52
# 4      41     667
# 5       3      18

# %% [markdown]
# ## .iloc()
# integer-location based indexing for selection by position

# %%
data.iloc[:4,:6]
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases
# 0    Afghanistan      36263    1269      25198    9796        106
# 1        Albania       4880     144       2745    1991        117
# 2        Algeria      27973    1163      18837    7973        616
# 3        Andorra        907      52        803      52         10

# %% [markdown]
# # Missing values in the dataset

# %% [markdown]
# ## .isnull()
# Detect missing values.

# %%
data.isnull()
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isna().any()
# Out:
# Country/Region            False
# Confirmed                 False
# Deaths                    False
# Recovered                 False
# Active                    False
# New cases                 False
# New deaths                False
# New recovered             False
# Deaths / 100 Cases        False
# Recovered / 100 Cases     False
# Deaths / 100 Recovered    False
# Confirmed last week       False
# 1 week change             False
# 1 week % increase         False
# WHO Region                False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %% [markdown]
# # Groupby Function

# %% [markdown]
# ## .groupby()
# This can be used to group large amounts of data and compute operations on these groups.

# %%
data[["Country/Region","Deaths","Active","Recovered","WHO Region"]].groupby(["Active","Recovered"]).sum()
# Out:
#                    Country/Region  Deaths       WHO Region
# Active  Recovered
# 0       12               Holy See       0           Europe
#         18               Dominica       0         Americas
#         23                Grenada       0         Americas
#         138                Brunei       3  Western Pacific
#         657            San Marino      42           Europe
# ...                           ...     ...              ...
# 201097  602249             Russia   13334           Europe
# 254427  1437       United Kingdom   45844           Europe
# 495499  951166              India   33408  South-East Asia
# 508116  1846641            Brazil   87618         Americas
# 2816444 1325804                US  148011         Americas
#
# [187 rows x 3 columns]

# %% [markdown]
# # Index

# %%
data.index
# Out:
# RangeIndex(start=0, stop=187, step=1)

# %% [markdown]
# # Columns

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# # Sort by values

# %% [markdown]
# ## .sort_values()
# Sort by the values along either axis.

# %%
data.sort_values(by='Recovered')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.sort_values(by='Recovered')
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Drop Columns

# %%
drop_cols = ['1 week % increase']
data.drop(drop_cols,axis=1,inplace=True)

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# # Insert column

# %% [markdown]
# ## .insert
# Insert a new column in the dataset.

# %%
#new column
new_col=np.random.randn(187)
#insert the new column at position 8
data.insert (13,'new_col',new_col)

# %%
data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data[["Country/Region","Deaths"]].head(10)
# Out:
#         Country/Region  Deaths
# 0          Afghanistan    1269
# 1              Albania     144
# 2              Algeria    1163
# 3              Andorra      52
# 4               Angola      41
# 5  Antigua and Barbuda       3
# 6            Argentina    3059
# 7              Armenia     711
# 8            Australia     167
# 9              Austria     713

# %%
data[["Country/Region","Deaths"]].tail(10)
# Out:
#          Country/Region  Deaths
# 177      United Kingdom   45844
# 178             Uruguay      35
# 179          Uzbekistan     121
# 180           Venezuela     146
# 181             Vietnam       0
# 182  West Bank and Gaza      78
# 183      Western Sahara       1
# 184               Yemen     483
# 185              Zambia     140
# 186            Zimbabwe      36

# %%
data[["Country/Region","Confirmed","Deaths"]].sort_values(by = "Confirmed",ascending = False).head(10)
# Out:
#      Country/Region  Confirmed  Deaths
# 173              US    4290259  148011
# 23           Brazil    2442375   87618
# 79            India    1480073   33408
# 138          Russia     816680   13334
# 154    South Africa     452529    7067
# 111          Mexico     395489   44022
# 132            Peru     389717   18418
# 35            Chile     347923    9187
# 177  United Kingdom     301708   45844
# 81             Iran     293606   15912

# %%
data[["WHO Region","Confirmed"]].groupby(["WHO Region"]).sum()
# Out:
#                        Confirmed
# WHO Region
# Africa                    723207
# Americas                 8839286
# Eastern Mediterranean    1490744
# Europe                   3299523
# South-East Asia          1835297
# Western Pacific           292428
